# %%
from sqlalchemy import create_engine

# %%
import pandas as pd

# %%
engine=create_engine('postgresql://administrator:cornellorie@rds-postgresql.clahixkkwlcw.us-east-1.rds.amazonaws.com:5432/stockdata')

# %%
df1=pd.read_sql_query('select * from "table20141201" LIMIT 50',con=engine)

# %%
df1
# Out:
#     id            a                                             b date_quote
# 0    1  092930003PA    T-00000016500000427800N000000000000002826C   20141201
# 1    2  093001173NA    O-00002702700000426900N000000000000003606C   20141201
# 2    3  093001293DA   4-00000700000000426900N000000000000003675CT   20141201
# 3    4  093001507TA    I-00000000200000426500N000000000000003744C   20141201
# 4    5  093001507TA    Q-00000000200000426500N000000000000003745C   20141201
# 5    6  093004113DA   @-00000010000000427100N000000000000004171CT   20141201
# 6    7  093004113DA   @-00000010000000427300N000000000000004173CT   20141201
# 7    8  093004149PA    Q-00000010000000427200N000000000000004218C   20141201
# 8    9  093004149PA    O-00000010000000427200N000000000000004219C   20141201
# 9   10  093004149PA    @-00000010000000427300N000000000000004220C   20141201
# 10  11  093004150KA    F-00000010000000427100N000000000000004225C   20141201
# ...

# %%
df2=pd.read_sql_query('select distinct * from table20141202 LIMIT 50',con=engine)

# %%
df2
# Out:
#       id            a                                            b date_quote
# 0    855  094424576ZA   @-00000010000000416700N000000000000096319C   20141202
# 1   3095  104200322DA  @-00000010000000418000N000000000000384717CT   20141202
# 2   2680  103031040TA   F-00000010000000417500N000000000000335438C   20141202
# 3   3533  105440448NA  F-I00000002900000418000N000000000000438197C   20141202
# 4   2450  102602261TA   F-00000010000000416000N000000000000314206C   20141202
# 5    387  093713452DA  @-00000020000000416150N000000000000052945CT   20141202
# 6   4455  112053228XA   F-00000010000000418000N000000000000562505C   20141202
# 7   1083  095033938JA   @-00000010000000415900N000000000000133039C   20141202
# 8   1660  100322164BA   F-00000010000000416900N000000000000199599C   20141202
# 9    374  093633707NA   F-00000020000000416100N000000000000048134C   20141202
# 10   940  094657344TA   F-00000020000000416600N000000000000111996C   20141202
# ...

# %%
df3=pd.read_sql_query('select * from table20141201 LEFT JOIN table20141202 ON table20141201.a = table20141202.a LIMIT 50',con=engine)

# %%
df3
# Out:
#       id            a                                            b date_quote  \
# 0    217  093440801PA   F-00000080000000424700N000000000000031831C   20141201
# 1    216  093440801PA   @-00000060000000424700N000000000000031830C   20141201
# 2   2998  105029694YA   @-00000010000000420700N000000000000456840C   20141201
# 3   4166  111116306PA   F-00000010000000420000N000000000000562957C   20141201
# 4   4020  110623810DA  @-00000010000000419900N000000000000537699CT   20141201
# 5    228  093443822DA  @-00000010000000424750N000000000000032113CT   20141201
# 6   2137  102338387ZA   F-00000010000000422800N000000000000320550C   20141201
# 7    969  094901974DA  @-00000010000000426000N000000000000131634CN   20141201
# 8   4058  110737668DA  @-00000010000000420000N000000000000543480CT   20141201
# 9   4167  111116853ZA   @-00000010000000420000N000000000000563010C   20141201
# 10  4126  111052606PA   @-00000010000000420000N000000000000559488C   20141201
# ...
